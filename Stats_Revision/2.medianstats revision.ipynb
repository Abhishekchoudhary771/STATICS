# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
n=len(k)
mid_pos=n//2
print("mid_pos:",mid_pos)
# Out:
# mid_pos: 5

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
n=len(k)
mid_pos=n//2
print("mid_pos:",mid_pos)
print ("value of middle position:",k[mid_pos])
# Out:
# mid_pos: 5
# value of middle position: 9

# %%
l=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]
print(l[0:16])
# Out:
# [12, 14, 15, 16, 18, 19, 22, 24, 25, 27, 29, 39, 40, 42, 45, 47]

# %%
n=len(l)
mid_pos= n//2
print("len:",n)
print("mid_pos:",mid_pos)
# Out:
# len: 17
# mid_pos: 8

# %%
M=[12,14,15]
print(M[0],M[1],M[2])
# Out:
# 12 14 15

# %%
n=len(M)
mid_pos= n//2
print("len:",n)
print("mid_pos:",mid_pos)
print("Value of mid pos:",M[mid_pos])
# Out:
# len: 3
# mid_pos: 1
# Value of mid pos: 14

# %%
N= [12,14,15,16,17]
print(N[0],N[1],N[2],N[3],N[4])
# Out:
# 12 14 15 16 17

# %%
n=len(N)
mid_pos= n//2
print("len:",n)
print("mid_pos:",mid_pos)
print("Value of mid pos:",N[mid_pos])
# Out:
# len: 5
# mid_pos: 2
# Value of mid pos: 15

# %%
p = [12,14,15,16]
# a. print the value of p[0],p[1],p[2],p[3]
print(p[0],p[1],p[2],p[3])
print(p[0:])
# Out:
# 12 14 15 16
# [12, 14, 15, 16]

# %%
#b. print the index of mid position of this list
n= len(p)
mid_pos1,mid_pos2 = n//2, n//2-1
print(mid_pos1,mid_pos2)
# Out:
# 2 1

# %%
# c. print the value at index of mid position of this list
print(p[mid_pos2],p[mid_pos1])
# Out:
# 14 15

# %%
Q=[12,14,15,16,18,19]
#a. print the value of Q[0],Q[1],Q[2],Q[3],Q[4],Q[5]
print(Q[0],Q[1],Q[2],Q[3],Q[4],Q[5])
print(Q[0:])
# Out:
# 12 14 15 16 18 19
# [12, 14, 15, 16, 18, 19]

# %%
#b. print the index of mid position of this list 
n= len(Q)
mid_pos1,mid_pos2 = n//2, n//2-1
print(mid_pos1,mid_pos2)
# Out:
# 3 2

# %%
# c. print the value at index of mid position of this list
print(Q[mid_pos2],p[mid_pos1])
# Out:
# 15 16

# %%
R = [12,14,15,16,18,19,20,22]
# #a. print the value of R[0],R[1],R[2],R[3],R[4],R[5]R[6]R[7]
print(R[0],R[1],R[2],R[3],R[4],R[5],R[6],R[7])
print(R[0:])
# Out:
# 12 14 15 16 18 19 20 22
# [12, 14, 15, 16, 18, 19, 20, 22]

# %%
#b. print the index of mid position of this list 
n= len(R)
mid_pos1,mid_pos2 = n//2, n//2-1
print(mid_pos1,mid_pos2)
# Out:
# 4 3

# %%
# c. print the value at index of mid position of this list
print(R[mid_pos2],R[mid_pos1])
# Out:
# 16 18

# %%
s = [12,14,15,16,18,19,20,22,24,27]
# #a. print the value of R[0],R[1],R[2],R[3],R[4],R[5]R[6]R[7]
print(s[0],s[1],s[2],s[3],s[4],s[5],s[6],s[7],s[8],s[9])
print(s[0:])
# Out:
# 12 14 15 16 18 19 20 22 24 27
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27]

# %%
#b. print the index of mid position of this list 
n= len(s)
mid_pos1 =  n//2
mid_pos2 = n//2-1
print(mid_pos1,mid_pos2)
# Out:
# 5 4

# %%
# c. print the value at index of mid position of this list
print(s[mid_pos2],s[mid_pos1])
# Out:
# 18 19
